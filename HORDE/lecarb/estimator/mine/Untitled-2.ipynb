# %%
import pickle
def save_data_to_file(data,file_name):
    save_addr="./lecarb/estimator/mine/vec_data/"+file_name
    with open(save_addr, 'wb') as f:
        pickle.dump(data, f)
    print("the vec data has been stored in "+save_addr)

def load_data_from_pkl_file(file_name):
    load_addr="./lecarb/estimator/mine/vec_data/"+file_name
    with open(load_addr, 'rb') as f:
        data = pickle.load(f)
    print("has successfully loaded data from "+load_addr)
    return data

# %%
import matplotlib.pyplot as plt
import numpy as np
load_addr="./distribution_data/new_original_"+"census13"+"_"+"original"+".pkl"
with open(load_addr, 'rb') as f:
    distribution_data = pickle.load(f)
print("has successfully loaded data from "+load_addr)

for attr_name,attr_distribution in distribution_data.items():
    # print(attr_name,attr_distribution)
    
    #打印出具体的每一个值出现了多少次
    #print(attr_distribution)
    
    [name,attr_type]=attr_name.split("\n")
    x=[]
    y=[]
    for i in attr_distribution:
        x.append(i[0])
        y.append(i[1])
    plt.plot(x, y, 'b*--', alpha=0.5, linewidth=1, label='census13')#'bo-'表示蓝色实线，数据点实心原点标注
    ## plot中参数的含义分别是横轴值，纵轴值，线的形状（'s'方块,'o'实心圆点，'*'五角星   ...，颜色，透明度,线的宽度和标签 ，

    plt.legend()  #显示上面的label
    plt.xlabel(attr_name) #x_label
    plt.ylabel('frequency')#y_label
    
    #plt.ylim(-1,1)#仅设置y轴坐标范围
    plt.show()
# Out:
# has successfully loaded data from ./distribution_data/new_original_census13_original.pkl

# %%
import matplotlib.pyplot as plt
import numpy as np
load_addr="./distribution_data/new_original_"+"power7"+"_"+"original"+".pkl"
with open(load_addr, 'rb') as f:
    distribution_data = pickle.load(f)
print("has successfully loaded data from "+load_addr)

for attr_name,attr_distribution in distribution_data.items():
    # print(attr_name,attr_distribution)
    
    #打印出具体的每一个值出现了多少次
    #print(attr_distribution)
    
    [name,attr_type]=attr_name.split("\n")
    x=[]
    y=[]
    for i in attr_distribution:
        x.append(i[0])
        y.append(i[1])
    plt.plot(x, y, 'b*--', alpha=0.5, linewidth=1, label='power7')#'bo-'表示蓝色实线，数据点实心原点标注
    ## plot中参数的含义分别是横轴值，纵轴值，线的形状（'s'方块,'o'实心圆点，'*'五角星   ...，颜色，透明度,线的宽度和标签 ，

    plt.legend()  #显示上面的label
    plt.xlabel(attr_name) #x_label
    plt.ylabel('frequency')#y_label
    
    #plt.ylim(-1,1)#仅设置y轴坐标范围
    plt.show()
# Out:
# has successfully loaded data from ./distribution_data/new_original_power7_original.pkl

# %%
import matplotlib.pyplot as plt
import numpy as np
load_addr="./distribution_data/new_original_"+"forest10"+"_"+"original"+".pkl"
with open(load_addr, 'rb') as f:
    distribution_data = pickle.load(f)
print("has successfully loaded data from "+load_addr)

for attr_name,attr_distribution in distribution_data.items():
    # print(attr_name,attr_distribution)
    
    #打印出具体的每一个值出现了多少次
    #print(attr_distribution)
    
    [name,attr_type]=attr_name.split("\n")
    x=[]
    y=[]
    for i in attr_distribution:
        x.append(i[0])
        y.append(i[1])
    plt.plot(x, y, 'b*--', alpha=0.5, linewidth=0.2, label='forest10')#'bo-'表示蓝色实线，数据点实心原点标注
    ## plot中参数的含义分别是横轴值，纵轴值，线的形状（'s'方块,'o'实心圆点，'*'五角星   ...，颜色，透明度,线的宽度和标签 ，

    plt.legend()  #显示上面的label
    plt.xlabel(attr_name) #x_label
    plt.ylabel('frequency')#y_label
    
    #plt.ylim(-1,1)#仅设置y轴坐标范围
    plt.show()
# Out:
# has successfully loaded data from ./distribution_data/new_original_forest10_original.pkl

# %%
import matplotlib.pyplot as plt
import numpy as np
load_addr="./distribution_data/new_original_"+"dmv11"+"_"+"original"+".pkl"
with open(load_addr, 'rb') as f:
    distribution_data = pickle.load(f)
print("has successfully loaded data from "+load_addr)

for attr_name,attr_distribution in distribution_data.items():
    # print(attr_name,attr_distribution)
    
    #打印出具体的每一个值出现了多少次
    #print(attr_distribution)
    
    [name,attr_type]=attr_name.split("\n")
    x=[]
    y=[]
    for i in attr_distribution:
        x.append(i[0])
        y.append(i[1])
    plt.plot(x, y, 'b*--', alpha=0.5, linewidth=0.2, label='dmv11')#'bo-'表示蓝色实线，数据点实心原点标注
    ## plot中参数的含义分别是横轴值，纵轴值，线的形状（'s'方块,'o'实心圆点，'*'五角星   ...，颜色，透明度,线的宽度和标签 ，

    plt.legend()  #显示上面的label
    plt.xlabel(attr_name) #x_label
    plt.ylabel('frequency')#y_label
    
    #plt.ylim(-1,1)#仅设置y轴坐标范围
    plt.show()
# Out:
# has successfully loaded data from ./distribution_data/new_original_dmv11_original.pkl
